# %% [markdown]
# <a href="https://colab.research.google.com/github/ellerywuyn/LEAR-lab/blob/main/new_bow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install profanity-filter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting profanity-filter
#   Downloading profanity_filter-1.3.3-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: cached-property<2.0,>=1.5 in /usr/local/lib/python3.10/dist-packages (from profanity-filter) (1.5.2)
# Collecting poetry-version<0.2.0,>=0.1.3
#   Downloading poetry_version-0.1.5-py2.py3-none-any.whl (13 kB)
# Collecting redis<4.0,>=3.2
#   Downloading redis-3.5.3-py2.py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.1/72.1 kB 7.9 MB/s eta 0:00:00
# Collecting ordered-set-stubs<0.2.0,>=0.1.3
#   Downloading ordered_set_stubs-0.1.3-py2.py3-none-any.whl (4.8 kB)
# Collecting spacy<3.0,>=2.0
#   Downloading spacy-2.3.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 43.2 MB/s eta 0:00:00
# Collecting ruamel.yaml<0.16.0,>=0.15.89
#   Downloading ruamel.yaml-0.15.100.tar.gz (318 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.6/318.6 kB 29.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting ordered-set<4.0,>=3.0
#   Downloading ordered-set-3.1.1.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting more-itertools<9.0,>=8.0
#   Downloading more_itertools-8.14.0-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.2/52.2 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<2.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from profanity-filter) (1.10.7)
# Collecting tomlkit<0.6.0,>=0.4.6
#   Downloading tomlkit-0.5.11-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<2.0,>=1.3->profanity-filter) (4.5.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.0,>=2.0->profanity-filter) (2.0.7)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.0,>=2.0->profanity-filter) (1.22.4)
# Collecting thinc<7.5.0,>=7.4.1
#   Downloading thinc-7.4.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 65.2 MB/s eta 0:00:00
# Collecting srsly<1.1.0,>=1.0.2
#   Downloading srsly-1.0.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 kB 20.6 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.0,>=2.0->profanity-filter) (67.7.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.0,>=2.0->profanity-filter) (3.0.8)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.0,>=2.0->profanity-filter) (2.27.1)
# Collecting wasabi<1.1.0,>=0.4.0
#   Downloading wasabi-0.10.1-py3-none-any.whl (26 kB)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.0,>=2.0->profanity-filter) (0.7.9)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.0,>=2.0->profanity-filter) (4.65.0)
# Collecting plac<1.2.0,>=0.9.6
#   Downloading plac-1.1.3-py2.py3-none-any.whl (20 kB)
# Collecting catalogue<1.1.0,>=0.0.7
#   Downloading catalogue-1.0.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.0,>=2.0->profanity-filter) (1.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.0,>=2.0->profanity-filter) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.0,>=2.0->profanity-filter) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.0,>=2.0->profanity-filter) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.0,>=2.0->profanity-filter) (3.4)
# Building wheels for collected packages: ordered-set, ruamel.yaml
#   Building wheel for ordered-set (setup.py) ... done
#   Created wheel for ordered-set: filename=ordered_set-3.1.1-py2.py3-none-any.whl size=7821 sha256=0fc28920fa2fe97fb2089f79f5c7c62b42d9e3bdb1d4a2b7e60d8615f68ce32c
#   Stored in directory: /root/.cache/pip/wheels/f3/a3/35/50c437871c2cb71fe4bcc5c31ef025554ea1bb9ae08d40a5b1
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for ruamel.yaml (setup.py) ... error
#   ERROR: Failed building wheel for ruamel.yaml
#   Running setup.py clean for ruamel.yaml
# Successfully built ordered-set
# Failed to build ruamel.yaml
# Installing collected packages: wasabi, ruamel.yaml, plac, tomlkit, srsly, redis, ordered-set-stubs, ordered-set, more-itertools, catalogue, thinc, poetry-version, spacy, profanity-filter
#   Attempting uninstall: wasabi
#     Found existing installation: wasabi 1.1.1
#     Uninstalling wasabi-1.1.1:
#       Successfully uninstalled wasabi-1.1.1
#   error: subprocess-exited-with-error
#
#   × Running setup.py install for ruamel.yaml did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Running setup.py install for ruamel.yaml ... error
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> ruamel.yaml
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.

# %%
from profanity_filter.types_ import (Words, Language, ProfaneWordDictionaries, ProfaneWordDictionariesAcceptable,
                                     Languages, LanguagesAcceptable, Nlps, Morphs, Spells, Substrings,
                                     TextSplittedByLanguage, ProfanityFilterError, Word, AnalysisType, AnalysesTypes)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-38b53bb8e980> in <cell line: 1>()
# ----> 1 from profanity_filter.types_ import (Words, Language, ProfaneWordDictionaries, ProfaneWordDictionariesAcceptable,
#       2                                      Languages, LanguagesAcceptable, Nlps, Morphs, Spells, Substrings,
#       3                                      TextSplittedByLanguage, ProfanityFilterError, Word, AnalysisType, AnalysesTypes)
#
# ModuleNotFoundError: No module named 'profanity_filter'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
def is_profane(self, text: str) -> bool:
    """Returns True if input_text contains any profane words, False otherwise"""
    return self._censor(text=text, return_bool=True)

# %%
def _is_profane_word(self, language: Language, word: str) -> bool:
      profane_word_dictionaries = (self.profane_word_dictionaries.values()
                                    if language is None else
                                    [self.profane_word_dictionaries[language]])
      return any(word in profane_word_dictionary for profane_word_dictionary in profane_word_dictionaries)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d37fa6fd4e36> in <cell line: 1>()
# ----> 1 def _is_profane_word(self, language: Language, word: str) -> bool:
#       2       profane_word_dictionaries = (self.profane_word_dictionaries.values()
#       3                                     if language is None else
#       4                                     [self.profane_word_dictionaries[language]])
#       5       return any(word in profane_word_dictionary for profane_word_dictionary in profane_word_dictionaries)
#
# NameError: name 'Language' is not defined

# %%
import re
import pandas as pd
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from collections import Counter
import itertools
import random
import plotly.graph_objs as go

# %%
tweets_df = pd.read_csv("/content/drive/MyDrive/labeled_data.csv")
new_bow = pd.read_csv("/content/drive/MyDrive/pruned_bow.csv", header = None)

# %%
new_bow
# Out:
#              0
# 0          @$$
# 1        ahole
# 2        amcik
# 3         anus
# 4    arschloch
# ..         ...
# 324     niccas
# 325        nig
# 326         ho
# 327     nigguh
# 328    niggahs
#
# [329 rows x 1 columns]

# %%
tweets_df
# Out:
#        Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0               0      3            0                   0        3      2
# 1               1      3            0                   3        0      1
# 2               2      3            0                   3        0      1
# 3               3      3            0                   2        1      1
# 4               4      6            0                   6        0      1
# ...           ...    ...          ...                 ...      ...    ...
# 24778       25291      3            0                   2        1      1
# 24779       25292      3            0                   1        2      2
# 24780       25294      3            0                   3        0      1
# 24781       25295      6            0                   6        0      1
# 24782       25296      3            0                   0        3      2
#
#                                                    tweet
# 0      !!! RT @mayasolovely: As a woman you shouldn't...
# 1      !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2      !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3      !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4      !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
# ...                                                  ...
# 24778  you's a muthaf***in lie &#8220;@LifeAsKing: @2...
# 24779  you've gone and broke the wrong heart baby, an...
# 24780  young buck wanna eat!!.. dat nigguh like I ain...
# 24781              youu got wild bitches tellin you lies
# 24782  ~~Ruffled | Ntac Eileen Dahlia - Beautiful col...
#
# [24783 rows x 7 columns]
